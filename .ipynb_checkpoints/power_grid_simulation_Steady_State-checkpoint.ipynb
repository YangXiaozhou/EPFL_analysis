# %%
import pandapower as pp
import pandapower.networks

net = pandapower.networks.case39()
net
# Out:
# This pandapower network includes the following parameter tables:
#    - bus (39 elements)
#    - load (21 elements)
#    - polynomial_cost (10 elements)
#    - gen (9 elements)
#    - line (34 elements)
#    - trafo (12 elements)
#    - bus_geodata (39 elements)
#    - ext_grid (1 element)
#  and the following results tables:
#    - res_line (34 elements)
#    - res_trafo (12 elements)
#    - res_bus (39 elements)
#    - res_gen (9 elements)
#    - res_ext_grid (1 element)
#    - res_load (21 elements)

# %%
pp.runpp(net)
net
# Out:
# This pandapower network includes the following parameter tables:
#    - bus (39 elements)
#    - load (21 elements)
#    - polynomial_cost (10 elements)
#    - gen (9 elements)
#    - line (34 elements)
#    - trafo (12 elements)
#    - bus_geodata (39 elements)
#    - ext_grid (1 element)
#  and the following results tables:
#    - res_line (34 elements)
#    - res_trafo (12 elements)
#    - res_bus (39 elements)
#    - res_gen (9 elements)
#    - res_ext_grid (1 element)
#    - res_load (21 elements)

# %%
net.res_bus
# Out:
#        vm_pu  va_degree           p_kw         q_kvar
# 0   1.039384 -13.536602   97600.000000   44200.000000
# 1   1.048494  -9.785267       0.000000       0.000000
# 2   1.030708 -12.276384  322000.000000    2400.000000
# 3   1.004460 -12.626734  500000.000000  184000.000000
# 4   1.006006 -11.192339       0.000000       0.000000
# 5   1.008226 -10.408330       0.000000       0.000000
# 6   0.998397 -12.755626  233800.000000   84000.000000
# 7   0.997872 -13.335844  522000.000000  176600.000000
# 8   1.038332 -14.178442    6500.000000  -66600.000000
# 9   1.017843  -8.170875       0.000000       0.000000
# 10  1.013386  -8.936966       0.000000       0.000000
# 11  1.000815  -8.998824    8530.000000   88000.000000
# 12  1.014923  -8.929927       0.000000       0.000000
# 13  1.012319 -10.715295       0.000000       0.000000
# 14  1.016185 -11.345399  320000.000000  153000.000000
# 15  1.032520 -10.033348  329000.000000   32300.000000
# ...

# %%
net.res_line
# Out:
#         p_from_kw    q_from_kvar        p_to_kw      q_to_kvar        pl_kw  \
# 0  -173699.968353  -40307.333418  174677.679494  -24357.905613   977.711141
# 1    76099.968353   -3892.666582  -76033.949144  -74752.541524    66.019208
# 2   319914.587166   88586.563724 -318579.541911 -100878.939507  1335.045255
# 3  -244592.266659   82973.576320  248928.896793  -93837.355150  4336.630133
# 4    37339.617644  113064.517040  -37131.889918 -132590.249252   207.727726
# 5   -40760.075733  -14585.577533   40777.386191   -7937.412649    17.310458
# 6  -197449.492824   -4089.870321  197758.676656   -4524.020631   309.183832
# 7  -265418.617258  -47319.880427  265990.108324   42482.102982   571.491066
# 8  -536936.553010  -43112.382528  537509.598620   46159.984178   573.045609
# 9   339177.876354   47636.403159 -338244.496440  -49386.631740   933.379915
# 10  453815.603371   81548.654671 -452555.015829  -73594.880814  1260.587542
# ...

# %%
# Line 1 out of service
net.line.in_service.loc[0] = False
net.line.loc[0]
# Out:
# name               None
# std_type           None
# from_bus              0
# to_bus                1
# length_km             1
# r_ohm_per_km    4.16587
# x_ohm_per_km    48.9193
# c_nf_per_km     1557.12
# max_i_ka        1.00409
# df                    1
# parallel              1
# type                 ol
# in_service        False
# Name: 0, dtype: object

# %%
pp.runpp(net)

# %%
net.res_line
# Out:
#         p_from_kw    q_from_kvar        p_to_kw      q_to_kvar        pl_kw  \
# 0        0.000000       0.000000       0.000000       0.000000     0.000000
# 1   -97600.000000  -44200.000000   97690.399003  -32926.912579    90.399003
# 2   461293.685083   92011.985628 -458634.558837  -88791.341194  2659.126245
# 3  -211293.685083   65424.784746  214491.332995  -77615.983288  3197.647913
# 4   157095.579721  108107.853416 -156615.089268 -123023.461893   480.490453
# 5   -20461.020883  -21716.512222   20466.514588    -828.852412     5.493704
# 6   -81144.457674   -8163.961927   81197.014898   -4461.414947    52.557225
# 7  -262240.453058  -52812.576180  262806.007681   47957.775494   565.554622
# 8  -519537.034390  -49699.875282  520079.037785   52376.826877   542.003395
# 9   438340.019492   54161.290228 -436779.321674  -47000.134114  1560.697818
# 10  531025.973816   89535.692519 -529295.319067  -74280.319044  1730.654749
# ...

# %%
net.res_bus
# Out:
#        vm_pu  va_degree           p_kw         q_kvar
# 0   1.027659 -22.484887   97600.000000   44200.000000
# 1   1.046582  -6.423586       0.000000       0.000000
# 2   1.027617 -10.063394  322000.000000    2400.000000
# 3   1.001280 -11.840241  500000.000000  184000.000000
# 4   1.002166 -11.247830       0.000000       0.000000
# 5   1.004525 -10.484419       0.000000       0.000000
# 6   0.993794 -13.256648  233800.000000   84000.000000
# 7   0.992970 -14.047257  522000.000000  176600.000000
# 8   1.033914 -18.454396    6500.000000  -66600.000000
# 9   1.015385  -7.843140       0.000000       0.000000
# 10  1.010440  -8.738428       0.000000       0.000000
# 11  0.998059  -8.674162    8530.000000   88000.000000
# 12  1.012501  -8.478693       0.000000       0.000000
# 13  1.009840  -9.943777       0.000000       0.000000
# 14  1.014270  -9.916216  320000.000000  153000.000000
# 15  1.031054  -8.319450  329000.000000   32300.000000
# ...
